# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import math
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

import matplotlib.pyplot as plt
# Read dataset into a DataFrame
df = pd.read_csv("dataset2_cleaned.csv")
df2 = pd.read_csv("dataset1_cleaned.csv")

# %% [markdown]
# # Rat Arrival Number vs Bat Landing Number

# %%
# Separate explanatory variables (x) from the response variable (y)
x = df[['rat_arrival_number']]
y = df['bat_landing_number']

# Split dataset into 80% training and 40% test sets 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Build a linear regression model
model = LinearRegression()

# Train (fit) the linear regression model using the training set
model.fit(X_train, y_train)

# Print the intercept and coefficient learned by the linear regression model
print("Intercept: ", model.intercept_)
print("Coefficient: ", model.coef_)

# Use linear regression to predict the values of (y) in the test set
# based on the values of x in the test set
y_pred = model.predict(X_test)

# Compute standard performance metrics of the linear regression:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Normalised Root Mean Square Error
y_max = y_test.max()
y_min = y_test.min()
rmse_norm = rmse / (y_max - y_min)
# R-Squared
r_2 = metrics.r2_score(y_test, y_pred)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)
print("R^2: ", r_2)


# COMPARE THE PERFORMANCE OF THE LINEAR REGRESSION MODEL
# VS.
# A DUMMY MODEL (BASELINE) THAT USES MEAN AS THE BASIS OF ITS PREDICTION

print("\n##### BASELINE MODEL #####")

# Compute mean of values in (y) training set
y_base = np.mean(y_train)
# Replicate the mean values as many times as there are values in the test set
y_pred_base = [y_base] * len(y_test)

# Compute standard performance metrics of the baseline model:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred_base)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred_base)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred_base))
# Normalised Root Mean Square Error
rmse_norm = rmse / (y_max - y_min)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)

# Scatter plot of actual test data
plt.scatter(X_test, y_test, color='blue', label='Actual')

# Plot the regression line using predicted values
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')

# Add labels and title
plt.xlabel('Rat Arrival Number')
plt.ylabel('Bat Landing Number')
plt.title('Linear Regression: Rat Arrival vs Bat Landing')
plt.legend()

# Show the plot
plt.show()
# Out:
# Intercept:  31.806783895831096
# Coefficient:  [-2.81487969]
# MAE:  18.735288019996
# MSE:  509.64959834359723
# RMSE:  22.575420225182903
# RMSE (Normalised):  0.22575420225182902
# R^2:  0.004010610885030075
#
# ##### BASELINE MODEL #####
# MAE:  18.778104344211187
# MSE:  511.71527381098986
# RMSE:  22.621124503679958
# RMSE (Normalised):  0.22621124503679957

# %% [markdown]
# ## Explenation

# %% [raw]
# NRMSE of the model is low, which shows it's a reliable model.
# Baseline model was done with mean, and while the difference between them is inconsequencial, the model still proved more accurate.
#
# r2 is only 0.004, which indicates that there is practically no relation between the 2 variables.
# For the bats to fear the rats, we'd expect a strong negative correlation (showing that bats do not want to be near rats). Instead it appears that the bats do not avoid the rats in any meaningful capacity.
# coefficient implies a small negative correlation.

# %% [markdown]
# # risk vs time to food

# %%
# Separate explanatory variables (x) from the response variable (y)
x = df2[['risk']]
y = df2['bat_landing_to_food_min']

# Split dataset into 80% training and 40% test sets 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Build a linear regression model
model = LinearRegression()

# Train (fit) the linear regression model using the training set
model.fit(X_train, y_train)

# Print the intercept and coefficient learned by the linear regression model
print("Intercept: ", model.intercept_)
print("Coefficient: ", model.coef_)

# Use linear regression to predict the values of (y) in the test set
# based on the values of x in the test set
y_pred = model.predict(X_test)

# Compute standard performance metrics of the linear regression:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Normalised Root Mean Square Error
y_max = y_test.max()
y_min = y_test.min()
rmse_norm = rmse / (y_max - y_min)
# R-Squared
r_2 = metrics.r2_score(y_test, y_pred)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)
print("R^2: ", r_2)


# COMPARE THE PERFORMANCE OF THE LINEAR REGRESSION MODEL
# VS.
# A DUMMY MODEL (BASELINE) THAT USES MEAN AS THE BASIS OF ITS PREDICTION

print("\n##### BASELINE MODEL #####")

# Compute mean of values in (y) training set
y_base = np.mean(y_train)
# Replicate the mean values as many times as there are values in the test set
y_pred_base = [y_base] * len(y_test)

# Compute standard performance metrics of the baseline model:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred_base)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred_base)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred_base))
# Normalised Root Mean Square Error
rmse_norm = rmse / (y_max - y_min)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)

# Scatter plot of actual test data
plt.scatter(X_test, y_test, color='blue', label='Actual')

# Plot the regression line using predicted values
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')

# Add labels and title
plt.xlabel('Risk Taken')
plt.ylabel('Time between Landing and Eating')
plt.title('Linear Regression: Risk vs Bat Time to Food')
plt.legend()

# Show the plot
plt.show()
# Out:
# Intercept:  0.0683982213321491
# Coefficient:  [0.04977785]
# MAE:  0.07412010511466459
# MSE:  0.009813834524142516
# RMSE:  0.09906479962197731
# RMSE (Normalised):  0.22870670485095257
# R^2:  0.03306710100207477
#
# ##### BASELINE MODEL #####
# MAE:  0.07521825098969354
# MSE:  0.010149857957115208
# RMSE:  0.10074650344858231
# RMSE (Normalised):  0.2325891832104277

# %% [raw]
# NRMSE of the model is low, which shows it's a reliable model.
# Baseline model was done with mean, and while the difference between them is inconsequencial, the model still proved more accurate.
#
# r2 is only 0.03, which indicates that there is practically no relation between the 2 variables.\
# If it is considered a risk for bats to spend less time to start eating, from when they arrive on the food platform (being less vigilant and hesitant), it could indicate that they find the area around the food platfrom dangerous (most likely from rats). This however is not the case, as there is no indication that the amount of time before eating is related to if the bats are taking a risk.

# %%
# Time to food vs rat present

# %%
# Separate explanatory variables (x) from the response variable (y)
x = df[['rat_arrival_number']]
y = df['food_availability']

# Split dataset into 80% training and 40% test sets 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Build a linear regression model
model = LinearRegression()

# Train (fit) the linear regression model using the training set
model.fit(X_train, y_train)

# Print the intercept and coefficient learned by the linear regression model
print("Intercept: ", model.intercept_)
print("Coefficient: ", model.coef_)

# Use linear regression to predict the values of (y) in the test set
# based on the values of x in the test set
y_pred = model.predict(X_test)

# Compute standard performance metrics of the linear regression:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Normalised Root Mean Square Error
y_max = y_test.max()
y_min = y_test.min()
rmse_norm = rmse / (y_max - y_min)
# R-Squared
r_2 = metrics.r2_score(y_test, y_pred)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)
print("R^2: ", r_2)


# COMPARE THE PERFORMANCE OF THE LINEAR REGRESSION MODEL
# VS.
# A DUMMY MODEL (BASELINE) THAT USES MEAN AS THE BASIS OF ITS PREDICTION

print("\n##### BASELINE MODEL #####")

# Compute mean of values in (y) training set
y_base = np.mean(y_train)
# Replicate the mean values as many times as there are values in the test set
y_pred_base = [y_base] * len(y_test)

# Compute standard performance metrics of the baseline model:
# Mean Absolute Error
mae = metrics.mean_absolute_error(y_test, y_pred_base)
# Mean Squared Error
mse = metrics.mean_squared_error(y_test, y_pred_base)
# Root Mean Square Error
rmse =  math.sqrt(metrics.mean_squared_error(y_test, y_pred_base))
# Normalised Root Mean Square Error
rmse_norm = rmse / (y_max - y_min)

print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("RMSE (Normalised): ", rmse_norm)

# Scatter plot of actual test data
plt.scatter(X_test, y_test, color='blue', label='Actual')

# Plot the regression line using predicted values
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')

# Add labels and title
plt.xlabel('Rat Arrival Number')
plt.ylabel('Food Availability')
plt.title('Linear Regression: Rat Arrival vs Food Availability')
plt.legend()

# Show the plot
plt.show()
# Out:
# Intercept:  2.7556579812649535
# Coefficient:  [-0.12521672]
# MAE:  0.7805682525388676
# MSE:  0.8975260436284278
# RMSE:  0.9473785112764738
# RMSE (Normalised):  0.2631606975767983
# R^2:  0.0049685249841388
#
# ##### BASELINE MODEL #####
# MAE:  0.7829934642458128
# MSE:  0.902504646132482
# RMSE:  0.9500024453297381
# RMSE (Normalised):  0.2638895681471495

# %% [raw]
# NRMSE of the model is low, which shows it's a reliable model.
# Baseline model was done with mean, and while the difference between them is inconsequencial, the model still proved more accurate.
# r2 is only 0.004, which indicates that there is practically no relation between the 2 variables.
#
# If the bats were afraid of the rats, the bats may not have the confidence to eat as much food when in the presents of rats (thus meaning there would be more total food available with more rats). This however is not the case, as it seems that bats eat the same amount regardless of the number of rats present.
